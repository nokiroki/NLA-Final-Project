# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.sparse.linalg as splin
import scipy.sparse as sparse
import json


import random
import pandas as pd
import numpy as np

import scipy.sparse as sparse
from scipy.sparse.linalg import spsolve
from sklearn.preprocessing import MinMaxScaler
from tqdm.notebook import tqdm

from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import ndcg_score as ndcg
from sklearn.metrics import recall_score as recall
# from ignite.metrics.recall import Recall as t_recall
import torch

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# 1 million MovieLens 

df_ratings = pd.read_csv('ml-1m/ratings.dat', sep="::", header=None)
df_ratings.columns = ['user_id', 'object_id', 'rating', 'timestamp']
df_ratings.drop('timestamp', axis='columns', inplace=True)
df_ratings.dropna(inplace=True)
df_ratings['user_id'] = df_ratings['user_id'].astype("category").cat.codes
df_ratings['object_id'] = df_ratings['object_id'].astype("category").cat.codes
df_ratings
# Out:
#          user_id  object_id  rating
# 0              0       1104       5
# 1              0        639       3
# 2              0        853       3
# 3              0       3177       4
# 4              0       2162       5
# ...          ...        ...     ...
# 1000204     6039       1019       1
# 1000205     6039       1022       5
# 1000206     6039        548       5
# 1000207     6039       1024       4
# 1000208     6039       1025       4
#
# [1000209 rows x 3 columns]

# %%
def form_sparse_matrix(df, rows='user_id', columns='object_id'):
    rows = df[rows].astype("int")
    cols = df[columns].astype("int")

    ratings = df.rating.astype("int")

    data_sparse = sparse.csr_matrix(
        (ratings, (rows, cols)), 
        shape=(
            df.user_id.nunique(), 
            df.object_id.nunique() 
        ), 
        dtype='int32'
    )

    return data_sparse

# %%
import random

random.seed = 123
random.sample([1, 2, 3], k=2)
# Out:
# [3, 2]

# %%
def train_test_split(df, user_col, item_col='object_id', test_size=0.5):
    test_indices = []
    for user in df[user_col].unique():
        df1 = df[df[user_col] == user]
        print(int(len(df1)*test_size))
        test_ind = random.sample(df[item_col].index, k=int(len(df1)*test_size))
        test_indices.extend(test_ind)
    test_data = df.iloc[test_indices]
    train_data = df.drop(test_indices, axis=0)
    return train_data, test_data

# %%
df_ratings
# Out:
#          user_id  object_id  rating
# 0              0       1104       5
# 1              0        639       3
# 2              0        853       3
# 3              0       3177       4
# 4              0       2162       5
# ...          ...        ...     ...
# 1000204     6039       1019       1
# 1000205     6039       1022       5
# 1000206     6039        548       5
# 1000207     6039       1024       4
# 1000208     6039       1025       4
#
# [1000209 rows x 3 columns]

# %%
train_data, test_data = train_test_split(df_ratings, 'user_id', item_col='object_id', test_size=0.5)
train_data.shape + test_data.shape
# Out:
# 26
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8a8a48c2310c> in <module>
# ----> 1 train_data, test_data = train_test_split(df_ratings, 'user_id', item_col='object_id', test_size=0.5)
#       2 train_data.shape + test_data.shape
#
# <ipython-input-30-f59da167535f> in train_test_split(df, user_col, item_col, test_size)
#       4         df1 = df[df[user_col] == user]
#       5         print(int(len(df1)*test_size))
# ----> 6         test_ind = random.sample(df[item_col].index, k=int(len(df1)*test_size))
#       7         test_indices.extend(test_ind)
#       8     test_data = df.iloc[test_indices]
#
# ~\Anaconda3\lib\random.py in sample(self, population, k)
#     357             population = tuple(population)
#     358         if not isinstance(population, _Sequence):
# --> 359             raise TypeError("Population must be a sequence or set.  For dicts, use list(d).")
#     360         randbelow = self._randbelow
#     361         n = len(population)
#
# TypeError: Population must be a sequence or set.  For dicts, use list(d).

# %%
a = df_ratings[df_ratings.index < 10]

# %%
a
# Out:
#    user_id  object_id  rating
# 0        0       1104       5
# 1        0        639       3
# 2        0        853       3
# 3        0       3177       4
# 4        0       2162       5
# 5        0       1107       3
# 6        0       1195       5
# 7        0       2599       5
# 8        0        580       4
# 9        0        858       4

# %%
a[~a.index.isin([3, 4])]
# Out:
#    user_id  object_id  rating
# 0        0       1104       5
# 1        0        639       3
# 2        0        853       3
# 5        0       1107       3
# 6        0       1195       5
# 7        0       2599       5
# 8        0        580       4
# 9        0        858       4

# %%
a
# Out:
#    user_id  object_id  rating
# 0        0       1104       5
# 1        0        639       3
# 2        0        853       3
# 3        0       3177       4
# 4        0       2162       5
# 5        0       1107       3
# 6        0       1195       5
# 7        0       2599       5
# 8        0        580       4
# 9        0        858       4

# %%
a.drop([5, 6, 7], axis=0)
# Out:
#    user_id  object_id  rating
# 0        0       1104       5
# 1        0        639       3
# 2        0        853       3
# 3        0       3177       4
# 4        0       2162       5
# 8        0        580       4
# 9        0        858       4

# %%
a.iloc[5]
# Out:
# user_id         0
# object_id    1107
# rating          3
# Name: 5, dtype: int64

# %%
a
# Out:
#    user_id  object_id  rating
# 0        0       1104       5
# 1        0        639       3
# 2        0        853       3
# 3        0       3177       4
# 4        0       2162       5
# 5        0       1107       3
# 6        0       1195       5
# 7        0       2599       5
# 8        0        580       4
# 9        0        858       4
